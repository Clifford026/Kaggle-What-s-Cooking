# %%
# Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

import json

# %%
with open('train.json') as data_file:    
    data = json.load(data_file)

# %%
train_data=pd.DataFrame(data)

# %%
train_data
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %%
train_data["ingredients"][0]
# Out:
# ['romaine lettuce',
#  'black olives',
#  'grape tomatoes',
#  'garlic',
#  'pepper',
#  'purple onion',
#  'seasoning',
#  'garbanzo beans',
#  'feta cheese crumbles']

# %%
#train_data['ingredients_clean_string'] = [' , '.join(z).strip() for z in train_data['ingredients']]

# %%
train_data[

# %%
#train_data['ingredients_clean_string'] = train_data['ingredients_clean_string'].split(" , ")

# %%
ingredients_type = {}
for i in range(39774):
    for j in train_data['ingredients'][i]:
        if j not in ingredients_type:
            ingredients_type[j] = 0

# %%
ingredients_type
# Out:
# {'romaine lettuce': 0,
#  'black olives': 0,
#  'grape tomatoes': 0,
#  'garlic': 0,
#  'pepper': 0,
#  'purple onion': 0,
#  'seasoning': 0,
#  'garbanzo beans': 0,
#  'feta cheese crumbles': 0,
#  'plain flour': 0,
#  'ground pepper': 0,
#  'salt': 0,
#  'tomatoes': 0,
#  'ground black pepper': 0,
#  'thyme': 0,
#  'eggs': 0,
#  'green tomatoes': 0,
#  'yellow corn meal': 0,
#  'milk': 0,
#  'vegetable oil': 0,
#  'mayonaise': 0,
#  'cooking oil': 0,
#  'green chilies': 0,
#  'grilled chicken breasts': 0,
#  'garlic powder': 0,
#  'yellow onion': 0,
#  'soy sauce': 0,
#  'butter': 0,
#  'chicken livers': 0,
#  'water': 0,
#  'wheat': 0,
#  'black pepper': 0,
#  'shallots': 0,
#  'cornflour': 0,
#  'cayenne pepper': 0,
#  'onions': 0,
#  'garlic paste': 0,
#  'lemon juice': 0,
#  'chili powder': 0,
#  'passata': 0,
#  'oil': 0,
#  'ground cumin': 0,
#  'boneless chicken skinless thigh': 0,
#  'garam masala': 0,
#  'double cream': 0,
#  'natural yogurt': 0,
#  'bay leaf': 0,
#  'sugar': 0,
#  'fresh ginger root': 0,
#  'ground cinnamon': 0,
#  'vanilla extract': 0,
#  'ground ginger': 0,
#  'powdered sugar': 0,
#  'baking powder': 0,
#  'olive oil': 0,
#  'medium shrimp': 0,
#  'chopped cilantro': 0,
#  'jalapeno chilies': 0,
#  'flat leaf parsley': 0,
#  'skirt steak': 0,
#  'white vinegar': 0,
#  'sea salt': 0,
#  'chorizo sausage': 0,
#  'pistachio nuts': 0,
#  'white almond bark': 0,
#  'flour': 0,
#  'almond extract': 0,
#  'dried cranberries': 0,
#  'fresh pineapple': 0,
#  'pork': 0,
#  'poblano peppers': 0,
#  'corn tortillas': 0,
#  'cheddar cheese': 0,
#  'iceberg lettuce': 0,
#  'lime': 0,
#  'chopped cilantro fresh': 0,
#  'chopped tomatoes': 0,
#  'fresh basil': 0,
#  'extra-virgin olive oil': 0,
#  'kosher salt': 0,
#  'pimentos': 0,
#  'sweet pepper': 0,
#  'dried oregano': 0,
#  'sharp cheddar cheese': 0,
#  'swiss cheese': 0,
#  'provolone cheese': 0,
#  'canola oil': 0,
#  'mushrooms': 0,
#  'sausages': 0,
#  'low sodium soy sauce': 0,
#  'fresh ginger': 0,
#  'dry mustard': 0,
#  'green beans': 0,
#  'white pepper': 0,
#  'sesame oil': 0,
#  'scallions': 0,
#  'Shaoxing wine': 0,
#  'ground turkey': 0,
#  'crushed red pepper flakes': 0,
#  'corn starch': 0,
#  'Italian parsley leaves': 0,
#  'walnuts': 0,
#  'hot red pepper flakes': 0,
#  'fresh lemon juice': 0,
#  'trout fillet': 0,
#  'garlic cloves': 0,
#  'chipotle chile': 0,
#  'fine sea salt': 0,
#  'fresh cilantro': 0,
#  'ground coriander': 0,
#  'plum tomatoes': 0,
#  'avocado': 0,
#  'lime juice': 0,
#  'flank steak': 0,
#  'fresh parmesan cheese': 0,
#  'all-purpose flour': 0,
#  'fat free less sodium chicken broth': 0,
#  'chopped fresh chives': 0,
#  'gruyere cheese': 0,
#  'bacon slices': 0,
#  'gnocchi': 0,
#  'fat free milk': 0,
#  'cooking spray': 0,
#  'tumeric': 0,
#  'vegetable stock': 0,
#  'naan': 0,
#  'red lentils': 0,
#  'red chili peppers': 0,
#  'spinach': 0,
#  'sweet potatoes': 0,
#  'greek yogurt': 0,
#  'lemon curd': 0,
#  'confectioners sugar': 0,
#  'raspberries': 0,
#  'italian seasoning': 0,
#  'broiler-fryer chicken': 0,
#  'zesty italian dressing': 0,
#  'hot chili': 0,
#  'asian fish sauce': 0,
#  'red bell pepper': 0,
#  'chicken broth': 0,
#  'yellow squash': 0,
#  'garlic chili sauce': 0,
#  'sliced green onions': 0,
#  'broccolini': 0,
#  'fresh lime juice': 0,
#  'cooked rice': 0,
#  'chicken breasts': 0,
#  'pork loin': 0,
#  'roasted peanuts': 0,
#  'hoisin sauce': 0,
#  'creamy peanut butter': 0,
#  'chopped fresh mint': 0,
#  'thai basil': 0,
#  'rice': 0,
#  'rice noodles': 0,
#  'beansprouts': 0,
#  'roma tomatoes': 0,
#  'low-fat mayonnaise': 0,
#  'baking potatoes': 0,
#  'spicy brown mustard': 0,
#  'sesame seeds': 0,
#  'red pepper': 0,
#  'yellow peppers': 0,
#  'extra firm tofu': 0,
#  'broccoli': 0,
#  'orange bell pepper': 0,
#  'arrowroot powder': 0,
#  'red curry paste': 0,
#  'marinara sauce': 0,
#  'linguine': 0,
#  'capers': 0,
#  'olives': 0,
#  'lemon zest': 0,
#  'lo mein noodles': 0,
#  'light soy sauce': 0,
#  'dried black mushrooms': 0,
#  'chives': 0,
#  'oyster sauce': 0,
#  'dark soy sauce': 0,
#  'peanuts': 0,
#  'cabbage': 0,
#  'herbs': 0,
#  'fresh tomatoes': 0,
#  'paprika': 0,
#  'mango': 0,
#  'stock': 0,
#  'chile pepper': 0,
#  'sliced mushrooms': 0,
#  'sherry': 0,
#  'grated parmesan cheese': 0,
#  'heavy cream': 0,
#  'spaghetti': 0,
#  'cooked chicken': 0,
#  'green bell pepper': 0,
#  'egg roll wrappers': 0,
#  'sweet and sour sauce': 0,
#  'molasses': 0,
#  'shredded cabbage': 0,
#  'ground pork': 0,
#  'carrots': 0,
#  'flour tortillas': 0,
#  'cheese': 0,
#  'breakfast sausages': 0,
#  'large eggs': 0,
#  'boiling water': 0,
#  'hot sauce': 0,
#  'potatoes': 0,
#  'bacon': 0,
#  'fresh parsley': 0,
#  'andouille sausage': 0,
#  'cajun seasoning': 0,
#  'peanut oil': 0,
#  'celery': 0,
#  'ground red pepper': 0,
#  'shrimp': 0,
#  'onion powder': 0,
#  'firm tofu': 0,
#  'turnips': 0,
#  'palm sugar': 0,
#  'sliced chicken': 0,
#  'fish sauce': 0,
#  'lime wedges': 0,
#  'green papaya': 0,
#  'chile powder': 0,
#  'tamarind paste': 0,
#  'chinese chives': 0,
#  'crushed garlic': 0,
#  'green onions': 0,
#  'white sugar': 0,
#  'dried basil': 0,
#  'diced tomatoes': 0,
#  'Johnsonville Andouille Dinner Sausage': 0,
#  'parsley': 0,
#  'jambalaya rice mix': 0,
#  'worcestershire sauce': 0,
#  'hot pepper sauce': 0,
#  'creole seasoning': 0,
#  'bread slices': 0,
#  'great northern beans': 0,
#  'sage leaves': 0,
#  'chinese five-spice powder': 0,
#  'chicken thighs': 0,
#  'star anise': 0,
#  'cream cheese': 0,
#  'shredded cheddar cheese': 0,
#  'black-eyed peas': 0,
#  'tortilla chips': 0,
#  'collard greens': 0,
#  'ham hock': 0,
#  'chicken stock': 0,
#  'apple cider': 0,
#  'freshly ground pepper': 0,
#  'bay leaves': 0,
#  'rib': 0,
#  'light brown sugar': 0,
#  'large garlic cloves': 0,
#  'Oscar Mayer Deli Fresh Smoked Ham': 0,
#  'hoagie rolls': 0,
#  'salami': 0,
#  'giardiniera': 0,
#  'mozzarella cheese': 0,
#  'pepperoni': 0,
#  'ice cubes': 0,
#  'club soda': 0,
#  'white rum': 0,
#  'turbinado': 0,
#  'enchilada sauce': 0,
#  'picante sauce': 0,
#  'green pepper': 0,
#  'canned black beans': 0,
#  'shredded lettuce': 0,
#  'sour cream': 0,
#  'salmon fillets': 0,
#  'cumin seed': 0,
#  'curry powder': 0,
#  'serrano chile': 0,
#  'sauce': 0,
#  'chicken breast halves': 0,
#  'lettuce leaves': 0,
#  'chopped onion': 0,
#  'mandarin oranges': 0,
#  'orange liqueur': 0,
#  'yellow cake mix': 0,
#  'frosting': 0,
#  'fennel bulb': 0,
#  'lemon olive oil': 0,
#  'grapefruit juice': 0,
#  'white cornmeal': 0,
#  'bacon drippings': 0,
#  'buttermilk': 0,
#  'crab boil': 0,
#  'old bay seasoning': 0,
#  'crawfish': 0,
#  'sirloin': 0,
#  'mirin': 0,
#  'corn oil': 0,
#  'glass noodles': 0,
#  'sake': 0,
#  'shiitake': 0,
#  'napa cabbage': 0,
#  'whipping cream': 0,
#  'extra sharp cheddar cheese': 0,
#  'quickcooking grits': 0,
#  'monterey jack': 0,
#  'crushed red pepper': 0,
#  'mussels': 0,
#  'basil': 0,
#  'dry white wine': 0,
#  'finely chopped onion': 0,
#  'baking soda': 0,
#  'honey': 0,
#  'unsalted butter': 0,
#  'lemon': 0,
#  'pesto': 0,
#  'white wine': 0,
#  'bread crumbs': 0,
#  'curry': 0,
#  'low sodium beef broth': 0,
#  'pickapeppa sauce': 0,
#  'cold water': 0,
#  'allspice': 0,
#  'fresh thyme': 0,
#  'ground beef': 0,
#  'melted butter': 0,
#  'matcha green tea powder': 0,
#  'chopped walnuts': 0,
#  'coarse salt': 0,
#  'fenugreek': 0,
#  'urad dal': 0,
#  'white rice': 0,
#  'pizza crust': 0,
#  'part-skim mozzarella cheese': 0,
#  'yukon gold potatoes': 0,
#  'low-fat sour cream': 0,
#  'leeks': 0,
#  '1% low-fat milk': 0,
#  'lemongrass': 0,
#  'unsweetened coconut milk': 0,
#  'peanut sauce': 0,
#  'spareribs': 0,
#  'tamari soy sauce': 0,
#  'golden brown sugar': 0,
#  'dry sherry': 0,
#  'chicken legs': 0,
#  'ghee': 0,
#  'tomato paste': 0,
#  'ground turmeric': 0,
#  'cracked black pepper': 0,
#  'minced beef': 0,
#  'dried thyme': 0,
#  'ginger': 0,
#  'chillies': 0,
#  'crushed tomatoes': 0,
#  'fresh rosemary': 0,
#  'boneless pork loin': 0,
#  'pappardelle': 0,
#  'coconut milk': 0,
#  'eggplant': 0,
#  'jasmine rice': 0,
#  'Gochujang base': 0,
#  'top round steak': 0,
#  'rice vinegar': 0,
#  'Taiwanese bok choy': 0,
#  'vanilla': 0,
#  'large egg yolks': 0,
#  'orange juice concentrate': 0,
#  'pumpkin purÃ©e': 0,
#  'marshmallow creme': 0,
#  'toasted pecans': 0,
#  'maple syrup': 0,
#  'gingersnap': 0,
#  'ground nutmeg': 0,
#  'brown sugar': 0,
#  'serrano ham': 0,
#  'manchego cheese': 0,
#  'dijon mustard': 0,
#  'sourdough': 0,
#  'membrillo': 0,
#  'burger buns': 0,
#  'panko breadcrumbs': 0,
#  'chickpea flour': 0,
#  'Sriracha': 0,
#  'chickpeas': 0,
#  'ground flaxseed': 0,
#  'greens': 0,
#  'tahini': 0,
#  'ground cloves': 0,
#  'whole nutmegs': 0,
#  'ground cardamom': 0,
#  'Italian bread': 0,
#  'balsamic vinegar': 0,
#  'sausage casings': 0,
#  'shredded mozzarella cheese': 0,
#  'roasted red peppers': 0,
#  'penne pasta': 0,
#  'saffron': 0,
#  'warm water': 0,
#  'preserved lemon': 0,
#  'harissa': 0,
#  'couscous': 0,
#  'cayenne': 0,
#  'fat skimmed chicken broth': 0,
#  'pitted kalamata olives': 0,
#  'fat': 0,
#  'sweetened condensed milk': 0,
#  'ice': 0,
#  'espresso': 0,
#  'fresh asparagus': 0,
#  'pecans': 0,
#  'crumbled blue cheese': 0,
#  'chuck': 0,
#  'hamburger buns': 0,
#  'okra pods': 0,
#  'watercress': 0,
#  'self rising flour': 0,
#  'softened butter': 0,
#  'food colouring': 0,
#  'Madeira': 0,
#  'foie gras': 0,
#  'demi-glace': 0,
#  'sherry vinegar': 0,
#  'white bread': 0,
#  'Fuyu persimmons': 0,
#  'egg bread': 0,
#  'fenugreek leaves': 0,
#  'black mustard seeds': 0,
#  'amchur': 0,
#  'coriander': 0,
#  'fingerling potatoes': 0,
#  'ramps': 0,
#  'black peppercorns': 0,
#  'cinnamon sticks': 0,
#  'cardamom pods': 0,
#  'coriander seeds': 0,
#  'asiago': 0,
#  'whole wheat pasta': 0,
#  'sweet onion': 0,
#  'chestnuts': 0,
#  'granulated sugar': 0,
#  'whole milk ricotta cheese': 0,
#  'coffee ice cream': 0,
#  'mascarpone': 0,
#  'rum': 0,
#  'semisweet chocolate': 0,
#  'chestnut flour': 0,
#  'baby spinach leaves': 0,
#  'chopped garlic': 0,
#  'large shrimp': 0,
#  'barley': 0,
#  'cooked ham': 0,
#  'starchy potatoes': 0,
#  'grated nutmeg': 0,
#  'sirloin tip roast': 0,
#  'steak': 0,
#  'vegetable shortening': 0,
#  'finely chopped fresh parsley': 0,
#  'vinegar': 0,
#  'caul fat': 0,
#  'whole milk': 0,
#  'heavy whipping cream': 0,
#  'kahlÃºa': 0,
#  'instant espresso powder': 0,
#  'epazote': 0,
#  'radishes': 0,
#  'oregano': 0,
#  'white onion': 0,
#  'hominy': 0,
#  'tomatillos': 0,
#  'pepitas': 0,
#  'catfish fillets': 0,
#  'basmati rice': 0,
#  'cauliflower': 0,
#  'cumin': 0,
#  'blood orange': 0,
#  'low salt chicken broth': 0,
#  'white wine vinegar': 0,
#  'tomato sauce': 0,
#  'shredded carrots': 0,
#  'english muffins, split and toasted': 0,
#  'vegetable oil cooking spray': 0,
#  'chopped green bell pepper': 0,
#  'prawns': 0,
#  'rice flour': 0,
#  'seasoning salt': 0,
#  'lasagna noodles': 0,
#  'ranch dressing': 0,
#  'evaporated milk': 0,
#  'minced garlic': 0,
#  'red wine vinegar': 0,
#  'boneless chop pork': 0,
#  'chile paste': 0,
#  'lower sodium soy sauce': 0,
#  'dark sesame oil': 0,
#  'raisins': 0,
#  'pearl barley': 0,
#  'slivered almonds': 0,
#  'chocolate bars': 0,
#  'marshmallows': 0,
#  'cinnamon graham crackers': 0,
#  'chopped celery': 0,
#  'mustard powder': 0,
#  'cod': 0,
#  'minced onion': 0,
#  'dry bread crumbs': 0,
#  'golden raisins': 0,
#  'margarine': 0,
#  'mace': 0,
#  'brewed tea': 0,
#  'candied orange peel': 0,
#  'grated lemon zest': 0,
#  'dried currants': 0,
#  'rum extract': 0,
#  'dark brown sugar': 0,
#  'noodles': 0,
#  'baby bok choy': 0,
#  'black bean sauce': 0,
#  'red potato': 0,
#  'chinese rice wine': 0,
#  'black beans': 0,
#  'quinoa': 0,
#  'frozen corn': 0,
#  'vegetable broth': 0,
#  'yellow bell pepper': 0,
#  'orange': 0,
#  'duck': 0,
#  'dried mint flakes': 0,
#  'penne rigate': 0,
#  'feta cheese': 0,
#  'ras el hanout': 0,
#  'ground lamb': 0,
#  'large egg whites': 0,
#  '2% reduced-fat milk': 0,
#  'napa cabbage leaves': 0,
#  'chicken leg quarters': 0,
#  'cucumber': 0,
#  'long-grain rice': 0,
#  'crusty bread': 0,
#  'baby potatoes': 0,
#  'smoked streaky bacon': 0,
#  'piloncillo': 0,
#  'ground allspice': 0,
#  'hibiscus': 0,
#  'fresh oregano': 0,
#  'chocolate morsels': 0,
#  'cream sweeten whip': 0,
#  'instant espresso granules': 0,
#  'chocolate covered coffee beans': 0,
#  'unflavored gelatin': 0,
#  'pound cake': 0,
#  'pinenuts': 0,
#  'zucchini': 0,
#  'baby carrots': 0,
#  'fresh basil leaves': 0,
#  'asparagus spears': 0,
#  'frozen peas': 0,
#  'arborio rice': 0,
#  'yellow crookneck squash': 0,
#  'chipotles in adobo': 0,
#  'instant white rice': 0,
#  'cilantro leaves': 0,
#  'red beans': 0,
#  'skinless chicken thighs': 0,
#  'lime zest': 0,
#  'condensed cream of mushroom soup': 0,
#  'condensed cream of chicken soup': 0,
#  'lean ground beef': 0,
#  'Mexican cheese blend': 0,
#  'chunky salsa': 0,
#  'taco seasoning mix': 0,
#  'chorizo spanish': 0,
#  'pineapple juice': 0,
#  'dark rum': 0,
#  'daikon': 0,
#  'pork ribs': 0,
#  'goji berries': 0,
#  'oysters': 0,
#  'salsa': 0,
#  'demerara sugar': 0,
#  'egg whites': 0,
#  'fruit': 0,
#  'frozen pastry puff sheets': 0,
#  'mixed spice': 0,
#  'parsnips': 0,
#  'chili oil': 0,
#  'brown mustard seeds': 0,
#  'unsalted cashews': 0,
#  'thai green curry paste': 0,
#  'kecap manis': 0,
#  'frozen broad beans': 0,
#  'basil leaves': 0,
#  'chili flakes': 0,
#  'chicken tenderloin': 0,
#  'creole style seasoning': 0,
#  'condensed cheddar cheese soup': 0,
#  'refried beans': 0,
#  'grated jack cheese': 0,
#  'egg yolks': 0,
#  'asparagus': 0,
#  'fresh leav spinach': 0,
#  'cheese tortellini': 0,
#  'cherry tomatoes': 0,
#  'navy beans': 0,
#  'nonfat milk': 0,
#  'granny smith apples': 0,
#  'lard': 0,
#  'pecorino romano cheese': 0,
#  'fresh fava bean': 0,
#  'italian sausage': 0,
#  'pasta sheets': 0,
#  'spinach leaves': 0,
#  'low-fat natural yogurt': 0,
#  'Flora Cuisine': 0,
#  'curry paste': 0,
#  'bone-in chicken breasts': 0,
#  'white hominy': 0,
#  'dried chile peppers': 0,
#  'frozen whipped topping': 0,
#  'chocolate instant pudding': 0,
#  'instant butterscotch pudding mix': 0,
#  'graham cracker crumbs': 0,
#  'fennel seeds': 0,
#  'kalamata': 0,
#  'kielbasa': 0,
#  'celery ribs': 0,
#  'ham': 0,
#  'moong dal': 0,
#  'capsicum': 0,
#  'green mango': 0,
#  'toasted sesame oil': 0,
#  'tofu': 0,
#  'short-grain rice': 0,
#  'dried shiitake mushrooms': 0,
#  'gari': 0,
#  'Turkish bay leaves': 0,
#  'dried chickpeas': 0,
#  'semolina': 0,
#  'vine ripened tomatoes': 0,
#  'bittersweet chocolate': 0,
#  'fat free yogurt': 0,
#  'skim milk': 0,
#  'angel food cake': 0,
#  'unsweetened cocoa powder': 0,
#  'instant espresso': 0,
#  'organic chicken': 0,
#  'anise': 0,
#  'zinfandel': 0,
#  'orange blossom honey': 0,
#  'calimyrna figs': 0,
#  'clove': 0,
#  'plain whole-milk yogurt': 0,
#  'reduced sodium soy sauce': 0,
#  'beef stock': 0,
#  'chuck roast': 0,
#  'Corn Flakes Cereal': 0,
#  'coleslaw': 0,
#  'garlic salt': 0,
#  'chili paste': 0,
#  'red pepper flakes': 0,
#  'kiwi': 0,
#  'asian pear': 0,
#  'chees fresco queso': 0,
#  'swiss chard': 0,
#  'veal cutlets': 0,
#  'pasta': 0,
#  'wakame': 0,
#  'extra-lean ground beef': 0,
#  'scallion greens': 0,
#  'wonton wrappers': 0,
#  'peeled fresh ginger': 0,
#  'nonstick spray': 0,
#  'chopped fresh thyme': 0,
#  'chicken bones': 0,
#  'green bell pepper, slice': 0,
#  'anchovy fillets': 0,
#  'crusty rolls': 0,
#  'coconut oil': 0,
#  'almond flour': 0,
#  'coconut aminos': 0,
#  'green peas': 0,
#  'clams': 0,
#  'boneless skinless chicken breast halves': 0,
#  'seasoned rice wine vinegar': 0,
#  'snow peas': 0,
#  'hard-boiled egg': 0,
#  'artichoke hearts': 0,
#  'stuffing': 0,
#  'coriander powder': 0,
#  'maida flour': 0,
#  'pita bread rounds': 0,
#  'grated GruyÃ¨re cheese': 0,
#  'udon': 0,
#  'red miso': 0,
#  'silken tofu': 0,
#  'button mushrooms': 0,
#  'whole peeled tomatoes': 0,
#  'shredded Monterey Jack cheese': 0,
#  'pickled jalapenos': 0,
#  'broccoli rabe': 0,
#  'parmigiano reggiano cheese': 0,
#  'fontina': 0,
#  'thai chile': 0,
#  'peppercorns': 0,
#  'refrigerated piecrusts': 0,
#  'cream of chicken soup': 0,
#  'frozen peas and carrots': 0,
#  'low sodium chicken broth': 0,
#  'pasta sauce': 0,
#  'olive oil flavored cooking spray': 0,
#  'frozen chopped spinach': 0,
#  'part-skim ricotta cheese': 0,
#  'manicotti shells': 0,
#  'fettucine': 0,
#  'parmesan cheese': 0,
#  'chicken bouillon': 0,
#  'chili paste with garlic': 0,
#  'fresh veget': 0,
#  'taco sauce': 0,
#  'guacamole': 0,
#  'salsa verde': 0,
#  'condiments': 0,
#  'pork shoulder roast': 0,
#  'tortillas': 0,
#  'rose petals': 0,
#  'almonds': 0,
#  'pistachios': 0,
#  'chicken wings': 0,
#  'drumstick': 0,
#  'green chile': 0,
#  'peeled tomatoes': 0,
#  'chicken': 0,
#  'chiles': 0,
#  'adobo sauce': 0,
#  'ancho powder': 0,
#  'chipotle chile powder': 0,
#  'Old El Paso Flour Tortillas': 0,
#  'cranberry sauce': 0,
#  'beer': 0,
#  'chili sauce': 0,
#  'beef rib short': 0,
#  'miso paste': 0,
#  'seaweed': 0,
#  'dashi': 0,
#  'fresh dill': 0,
#  'yoghurt': 0,
#  'myzithra': 0,
#  'phyllo': 0,
#  'kefalotyri': 0,
#  'okra': 0,
#  'cracker crumbs': 0,
#  'Philadelphia Cream Cheese': 0,
#  'crab meat': 0,
#  'savoy cabbage': 0,
#  'boneless chicken thighs': 0,
#  'potato starch': 0,
#  'cream of tartar': 0,
#  'semi-sweet chocolate morsels': 0,
#  'cake flour': 0,
#  'ricotta cheese': 0,
#  'serrano': 0,
#  'steel-cut oats': 0,
#  'hazelnuts': 0,
#  'hazelnut oil': 0,
#  'sweet cherries': 0,
#  'fire roasted diced tomatoes': 0,
#  'red kidnei beans, rins and drain': 0,
#  'wasabi paste': 0,
#  'black sesame seeds': 0,
#  'Japanese soy sauce': 0,
#  'fresh salmon': 0,
#  'dried porcini mushrooms': 0,
#  'dry red wine': 0,
#  'hot water': 0,
#  'fat free less sodium beef broth': 0,
#  'cremini mushrooms': 0,
#  'creole mustard': 0,
#  'prepared horseradish': 0,
#  'celery salt': 0,
#  'shrimp and crab boil seasoning': 0,
#  'turnip greens': 0,
#  'butternut squash': 0,
#  'apples': 0,
#  'country ham': 0,
#  'frozen edamame beans': 0,
#  'whole kernel corn, drain': 0,
#  'strong white bread flour': 0,
#  'salted butter': 0,
#  'sunflower oil': 0,
#  'kalonji': 0,
#  'instant yeast': 0,
#  'fresh coriander': 0,
#  'cooked white rice': 0,
#  'mixed mushrooms': 0,
#  'wood ear mushrooms': 0,
#  'vegetables': 0,
#  'taco seasoning': 0,
#  'bell pepper': 0,
#  'boneless skinless chicken breasts': 0,
#  'shredded cheese': 0,
#  'eau de vie': 0,
#  'leaves': 0,
#  'cane sugar': 0,
#  'baking apples': 0,
#  'salt and ground black pepper': 0,
#  'sliced black olives': 0,
#  'chopped green chilies': 0,
#  'rosemary leaves': 0,
#  'lean steak': 0,
#  'Guinness Lager': 0,
#  'dried rosemary': 0,
#  'water chestnuts, drained and chopped': 0,
#  'chinese cabbage': 0,
#  'dipping sauces': 0,
#  'lean ground pork': 0,
#  'pico de gallo': 0,
#  'cheese slices': 0,
#  'chorizo': 0,
#  'french bread': 0,
#  'dried dillweed': 0,
#  'red wine': 0,
#  'lamb': 0,
#  'plain yogurt': 0,
#  'kale': 0,
#  'Mexican beer': 0,
#  'boneless beef short ribs': 0,
#  'guajillo': 0,
#  'saffron threads': 0,
#  'fresh spinach': 0,
#  'banana squash': 0,
#  'cannellini beans': 0,
#  'shortening': 0,
#  'Franks Hot Sauce': 0,
#  'pears': 0,
#  'light pancake syrup': 0,
#  'puff pastry': 0,
#  'apple cider vinegar': 0,
#  'mushroom powder': 0,
#  'bone in chicken thighs': 0,
#  'fresh bay leaves': 0,
#  'cilantro': 0,
#  'skinless chicken breasts': 0,
#  'light sour cream': 0,
#  'fava beans': 0,
#  'fresh tarragon': 0,
#  'kidney beans': 0,
#  'orzo pasta': 0,
#  'dri leav thyme': 0,
#  'wasabi': 0,
#  'jumbo shrimp': 0,
#  'sticky rice': 0,
#  'white sesame seeds': 0,
#  'chopped almonds': 0,
#  'baby arugula': 0,
#  'tequila': 0,
#  'margarita mix': 0,
#  'crust': 0,
#  'grits': 0,
#  'pecan halves': 0,
#  'corn syrup': 0,
#  'superfine sugar': 0,
#  'blackberries': 0,
#  'whiskey': 0,
#  'luke warm water': 0,
#  'active dry yeast': 0,
#  'fresh mint': 0,
#  'jamaican jerk season': 0,
#  'pineapple preserves': 0,
#  'chicken drumsticks': 0,
#  'pitas': 0,
#  'goat cheese': 0,
#  'gingerroot': 0,
#  'rib eye steaks': 0,
#  'hot bean paste': 0,
#  'medjool date': 0,
#  'diced bell pepper': 0,
#  'cream': 0,
#  'smoked paprika': 0,
#  'reduced fat milk': 0,
#  'smoked trout': 0,
#  'garlic puree': 0,
#  'green cardamom pods': 0,
#  'tomato purÃ©e': 0,
#  'pickled jalapeno peppers': 0,
#  'romaine lettuce leaves': 0,
#  'crema mexicana': 0,
#  'chile sauce': 0,
#  'queso fresco': 0,
#  'Boston lettuce': 0,
#  'persian cucumber': 0,
#  'peanut butter': 0,
#  'rice paper': 0,
#  'Korean chile flakes': 0,
#  'red chile powder': 0,
#  'boneless chicken breast': 0,
#  'cashew nuts': 0,
#  'kashmiri chile': 0,
#  'kasuri methi': 0,
#  'mustard oil': 0,
#  'ginger paste': 0,
#  'cinnamon': 0,
#  'tomato ketchup': 0,
#  'pecan pie': 0,
#  'tostada shells': 0,
#  'grouper': 0,
#  'corn kernels': 0,
#  'ricotta salata': 0,
#  'pecorino cheese': 0,
#  'grana padano': 0,
#  'kaffir lime leaves': 0,
#  'corn': 0,
#  'soba noodles': 0,
#  'galangal': 0,
#  'green curry paste': 0,
#  'bamboo shoots': 0,
#  'chopped nuts': 0,
#  'bourbon whiskey': 0,
#  'ketchup': 0,
#  'rhubarb': 0,
#  'liquid': 0,
#  'store bought low sodium chicken stock': 0,
#  'safflower oil': 0,
#  'jeera': 0,
#  'cardamom': 0,
#  'crema': 0,
#  'salmon steaks': 0,
#  'jam': 0,
#  'karashi': 0,
#  'spring onions': 0,
#  'free range egg': 0,
#  'jicama': 0,
#  'water chestnuts': 0,
#  'diced celery': 0,
#  'shredded sharp cheddar cheese': 0,
#  'dinner rolls': 0,
#  'cactus pad': 0,
#  'fenugreek seeds': 0,
#  'cauliflower flowerets': 0,
#  'boiling potatoes': 0,
#  'baby spinach': 0,
#  'tuna steaks': 0,
#  'spices': 0,
#  'octopuses': 0,
#  'vidalia onion': 0,
#  'smoked gouda': 0,
#  'small red potato': 0,
#  'tuna': 0,
#  'fat-free refried beans': 0,
#  'low-fat milk': 0,
#  'fresh lime': 0,
#  'ground white pepper': 0,
#  'BertolliÂ® Classico Olive Oil': 0,
#  'bacon, crisp-cooked and crumbled': 0,
#  'bertolli vineyard premium collect marinara with burgundi wine sauc': 0,
#  'bread crumb fresh': 0,
#  'margarita salt': 0,
#  '(    oz.) tomato sauce': 0,
#  'ground veal': 0,
#  'italian seasoning mix': 0,
#  'beef': 0,
#  'solid pack pumpkin': 0,
#  'fresh thyme leaves': 0,
#  'whole grain thin spaghetti': 0,
#  'grapeseed oil': 0,
#  'organic sugar': 0,
#  'dried cherry': 0,
#  'straw mushrooms': 0,
#  'vidalia': 0,
#  'haricots verts': 0,
#  'wax beans': 0,
#  'prosciutto': 0,
#  'romano cheese': 0,
#  'cooked shrimp': 0,
#  'crabmeat': 0,
#  'strawberries': 0,
#  'green peppercorns': 0,
#  'pork loin chops': 0,
#  'chipotle peppers': 0,
#  'blueberri preserv': 0,
#  'filet': 0,
#  'thyme leaves': 0,
#  'coffee beans': 0,
#  'vegan margarine': 0,
#  'pork shoulder': 0,
#  'parsley leaves': 0,
#  'fresh raspberries': 0,
#  'frozen whole kernel corn': 0,
#  'wish bone guacamol ranch dress': 0,
#  'torn romain lettuc leav': 0,
#  'russet potatoes': 0,
#  'mexican chorizo': 0,
#  'colby cheese': 0,
#  'half & half': 0,
#  'dry vermouth': 0,
#  'canned low sodium chicken broth': 0,
#  'roasted salted cashews': 0,
#  'fresh lemon': 0,
#  'toasted sesame seeds': 0,
#  'paneer cheese': 0,
#  'lemon grass': 0,
#  'Thai fish sauce': 0,
#  ...}

# %%
train_data["type"] = {}
'''for i in range(39774):
    for j in train_data['ingredients'][i]:
        if j not in ingredients_type:
            ingredients_type[j] = 0 '''
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-a80d8082995b> in <module>
# ----> 1 train_data["type"] = {}
#       2 '''for i in range(39774):
#       3     for j in train_data['ingredients'][i]:
#       4         if j not in ingredients_type:
#       5             ingredients_type[j] = 0 '''
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3038         else:
#    3039             # set column
# -> 3040             self._set_item(key, value)
#    3041
#    3042     def _setitem_slice(self, key: slice, value):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3114         """
#    3115         self._ensure_valid_index(value)
# -> 3116         value = self._sanitize_column(key, value)
#    3117         NDFrame._set_item(self, key, value)
#    3118
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3759
#    3760             # turn me into an ndarray
# -> 3761             value = sanitize_index(value, self.index)
#    3762             if not isinstance(value, (np.ndarray, Index)):
#    3763                 if isinstance(value, list) and len(value) > 0:
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in sanitize_index(data, index)
#     745     """
#     746     if len(data) != len(index):
# --> 747         raise ValueError(
#     748             "Length of values "
#     749             f"({len(data)}) "
#
# ValueError: Length of values (0) does not match length of index (39774)

# %%
X_train = pd.DataFrame(train_data["ingredients_clean_string"])
Y_train = pd.DataFrame(train_data["cuisine"])

# %%
train_data['ingredients_clean_string']

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
clf=RandomForestClassifier(n_estimators=100)

# %%
clf.fit(X_train,Y_train)
